# %%
import tensorflow as tf

# %%
enet = tf.keras.applications.efficientnet.EfficientNetB0(
    include_top=False,
    weights='imagenet',
    input_tensor=None,
    input_shape=(56,56,3),
    pooling=None,
    classes=10,
    classifier_activation='softmax')

# %%
enet.summary()
# Out:
# Model: "efficientnetb0"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_5 (InputLayer)            [(None, 56, 56, 3)]  0
# __________________________________________________________________________________________________
# rescaling_4 (Rescaling)         (None, 56, 56, 3)    0           input_5[0][0]
# __________________________________________________________________________________________________
# normalization_4 (Normalization) (None, 56, 56, 3)    7           rescaling_4[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 57, 57, 3)    0           normalization_4[0][0]
# __________________________________________________________________________________________________
# ...
